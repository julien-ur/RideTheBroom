# %%
import pandas as pd
import numpy as nd

# %%
temp_events = "subject_%d_events.csv"
temp_gamestatus = "subject_%d_gamestatus.csv"

subject_events = pd.read_csv(temp_events % 0, sep=";", keep_default_na=False)
print(df1)
# Out:
#      SubjectId  Timestamp EventType EventStatus                EventInfo  \
# 0            1      8.294      Ring     visible    (-17.7, 107.7, 129.2)
# 1            1     11.441      Ring     visible    (-22.9, 145.5, 178.4)
# 2            1     12.349      Ring     success
# 3            1     14.055      Ring     visible    (-38.3, 179.3, 216.7)
# 4            1     15.476      Ring     success
# 5            1     17.963       POV     visible                   Middle
# 6            1     18.169      Ring     visible    (-39.9, 226.9, 281.3)
# 7            1     18.203      Ring     success
# 8            1     22.938       POV     timeout
# 9            1     22.970      Ring     visible    (-33.5, 280.6, 358.3)
# 10           1     25.940      Ring     visible    (-30.0, 314.7, 406.9)
# 11           1     26.156      Ring     timeout
# 12           1     27.004      Ring     success
# 13           1     29.422       POV     visible                     Left
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read CSV (comma-separated) file into DataFrame
#
# ...

# %%
subject_events.Timestamp
# Out:
# 0         8.294
# 1        11.441
# 2        12.349
# 3        14.055
# 4        15.476
# 5        17.963
# 6        18.169
# 7        18.203
# 8        22.938
# 9        22.970
# 10       25.940
# 11       26.156
# 12       27.004
# 13       29.422
# 14       30.020
# 15       30.050
# 16       33.370
# 17       33.447
# 18       37.043
# 19       38.040
# 20       40.058
# 21       41.190
# 22       41.435
# 23       43.967
# 24       44.171
# 25       44.185
# 26       46.359
# 27       47.535
# 28       50.246
# 29       50.440
#          ...
# 236    1065.301
# 237    1068.810
# 238    1069.337
# 239    1072.674
# 240    1072.823
# 241    1075.601
# 242    1076.710
# 243    1077.660
# 244    1079.703
# 245    1079.859
# 246    1079.890
# 247    1082.123
# 248    1083.903
# 249    1084.515
# 250    1086.271
# 251    1088.268
# 252    1088.773
# 253    1090.327
# 254    1092.325
# 255    1092.549
# 256    1092.579
# 257    1096.592
# 258    1096.603
# 259    1098.991
# ...

# %%
subject_events.index = subject_events.pop('Timestamp')

# %%
subject_events.pop('SubjectId')
# Out:
# Timestamp
# 8.294       1
# 11.441      1
# 12.349      1
# 14.055      1
# 15.476      1
# 17.963      1
# 18.169      1
# 18.203      1
# 22.938      1
# 22.970      1
# 25.940      1
# 26.156      1
# 27.004      1
# 29.422      1
# 30.020      1
# 30.050      1
# 33.370      1
# 33.447      1
# 37.043      1
# 38.040      1
# 40.058      1
# 41.190      1
# 41.435      1
# 43.967      1
# 44.171      1
# 44.185      1
# 46.359      1
# 47.535      1
# 50.246      1
# 50.440      1
#            ..
# 1065.301    1
# 1068.810    1
# 1069.337    1
# 1072.674    1
# 1072.823    1
# 1075.601    1
# 1076.710    1
# 1077.660    1
# 1079.703    1
# 1079.859    1
# 1079.890    1
# 1082.123    1
# 1083.903    1
# 1084.515    1
# 1086.271    1
# 1088.268    1
# 1088.773    1
# 1090.327    1
# 1092.325    1
# 1092.549    1
# 1092.579    1
# 1096.592    1
# 1096.603    1
# 1098.991    1
# 1100.636    1
# 1101.984    1
# 1103.026    1
# 1104.043    1
# 1106.020    1
# 1107.025    1
# ...

# %%
subject_events.head()
# Out:
#           EventType EventStatus              EventInfo  EventId
# Timestamp
# 8.294          Ring     visible  (-17.7, 107.7, 129.2)  -287478
# 11.441         Ring     visible  (-22.9, 145.5, 178.4)  -287558
# 12.349         Ring     success                         -287478
# 14.055         Ring     visible  (-38.3, 179.3, 216.7)  -287668
# 15.476         Ring     success                         -287558

# %%
subject_events.groupby('EventId')
subject_events
# Out:
#           EventType EventStatus                EventInfo  EventId
# Timestamp
# 8.294          Ring     visible    (-17.7, 107.7, 129.2)  -287478
# 11.441         Ring     visible    (-22.9, 145.5, 178.4)  -287558
# 12.349         Ring     success                           -287478
# 14.055         Ring     visible    (-38.3, 179.3, 216.7)  -287668
# 15.476         Ring     success                           -287558
# 17.963          POV     visible                   Middle  -287818
# 18.169         Ring     visible    (-39.9, 226.9, 281.3)  -287946
# 18.203         Ring     success                           -287668
# 22.938          POV     timeout                           -287818
# 22.970         Ring     visible    (-33.5, 280.6, 358.3)  -288032
# 25.940         Ring     visible    (-30.0, 314.7, 406.9)  -288138
# 26.156         Ring     timeout                           -287946
# 27.004         Ring     success                           -288032
# ...
